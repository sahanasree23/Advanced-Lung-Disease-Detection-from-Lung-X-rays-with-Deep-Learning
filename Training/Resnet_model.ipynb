# %% [markdown]
# # **Using Tensorflow for detecting Covid-19 Infected Lungs from Normal Lungs with Chest X-Ray**
#
# Dataset collection and splitting into training and testing.

# %% [markdown]
# Dataset - Radioraphy with 3616 covid xray images and over 10,000 normal lungs images. We picked 3616 normal images to eliminate bias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.15.0

# %%
tf.random.set_seed(12)

# %%
from google.colab import drive
import zipfile
import os

# Mount Google Drive
drive.mount('/content/drive')

# Define the path to the zip file
zip_file_path = '/content/drive/My Drive/archive (3).zip'
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive

# %% [markdown]
# ### Use /tmp to create temporary folder

# %%
# !unzip '/content/drive/MyDrive/archive (3).zip' -d '/content/drive/MyDrive/dataset'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7921.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7922.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7923.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7924.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7925.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7926.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7927.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7928.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7929.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-793.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7930.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7931.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7932.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7933.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7934.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7935.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7936.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7937.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7938.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7939.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-794.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7940.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7941.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7942.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7943.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7944.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7945.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7946.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7947.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7948.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7949.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-795.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7950.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7951.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7952.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7953.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7954.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7955.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7956.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7957.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7958.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7959.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-796.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7960.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7961.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7962.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7963.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7964.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7965.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7966.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7967.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7968.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7969.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-797.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7970.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7971.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7972.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7973.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7974.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7975.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7976.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7977.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7978.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7979.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-798.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7980.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7981.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7982.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7983.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7984.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7985.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7986.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7987.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7988.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7989.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-799.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7990.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7991.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7992.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7993.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7994.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7995.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7996.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7997.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7998.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-7999.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-80.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-800.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8000.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8001.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8002.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8003.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8004.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8005.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8006.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8007.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8008.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8009.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-801.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8010.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8011.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8012.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8013.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8014.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8015.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8016.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8017.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8018.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8019.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-802.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8020.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8021.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8022.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8023.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8024.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8025.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8026.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8027.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8028.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8029.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-803.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8030.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8031.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8032.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8033.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8034.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8035.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8036.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8037.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8038.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8039.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-804.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8040.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8041.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8042.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8043.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8044.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8045.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8046.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8047.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8048.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8049.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-805.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8050.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8051.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8052.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8053.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8054.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8055.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8056.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8057.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8058.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8059.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-806.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8060.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8061.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8062.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8063.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8064.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8065.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8066.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8067.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8068.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8069.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-807.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8070.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8071.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8072.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8073.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8074.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8075.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8076.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8077.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8078.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8079.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-808.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8080.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8081.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8082.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8083.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8084.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8085.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8086.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8087.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8088.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8089.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-809.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8090.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8091.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8092.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8093.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8094.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8095.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8096.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8097.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8098.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8099.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-81.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-810.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8100.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8101.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8102.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8103.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8104.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8105.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8106.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8107.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8108.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8109.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-811.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8110.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8111.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8112.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8113.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8114.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8115.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8116.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8117.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8118.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8119.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-812.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8120.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8121.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8122.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8123.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8124.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8125.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8126.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8127.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8128.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8129.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-813.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8130.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8131.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8132.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8133.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8134.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8135.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8136.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8137.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8138.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8139.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-814.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8140.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8141.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8142.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8143.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8144.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8145.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8146.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8147.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8148.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8149.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-815.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8150.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8151.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8152.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8153.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8154.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8155.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8156.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8157.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8158.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8159.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-816.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8160.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8161.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8162.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8163.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8164.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8165.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8166.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8167.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8168.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8169.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-817.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8170.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8171.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8172.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8173.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8174.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8175.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8176.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8177.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8178.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8179.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-818.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8180.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8181.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8182.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8183.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8184.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8185.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8186.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8187.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8188.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8189.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-819.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8190.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8191.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8192.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8193.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8194.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8195.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8196.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8197.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8198.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8199.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-82.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-820.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8200.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8201.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8202.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8203.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8204.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8205.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8206.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8207.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8208.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8209.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-821.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8210.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8211.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8212.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8213.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8214.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8215.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8216.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8217.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8218.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8219.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-822.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8220.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8221.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8222.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8223.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8224.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8225.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8226.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8227.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8228.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8229.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-823.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8230.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8231.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8232.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8233.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8234.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8235.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8236.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8237.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8238.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8239.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-824.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8240.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8241.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8242.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8243.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8244.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8245.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8246.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8247.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8248.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8249.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-825.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8250.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8251.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8252.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8253.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8254.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8255.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8256.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8257.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8258.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8259.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-826.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8260.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8261.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8262.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8263.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8264.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8265.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8266.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8267.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8268.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8269.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-827.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8270.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8271.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8272.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8273.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8274.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8275.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8276.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8277.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8278.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8279.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-828.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8280.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8281.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8282.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8283.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8284.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8285.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8286.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8287.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8288.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8289.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-829.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8290.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8291.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8292.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8293.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8294.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8295.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8296.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8297.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8298.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8299.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-83.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-830.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8300.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8301.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8302.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8303.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8304.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8305.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8306.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8307.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8308.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8309.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-831.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8310.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8311.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8312.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8313.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8314.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8315.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8316.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8317.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8318.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8319.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-832.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8320.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8321.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8322.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8323.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8324.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8325.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8326.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8327.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8328.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8329.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-833.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8330.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8331.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8332.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8333.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8334.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/masks/Normal-8335.png
# ...
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-880.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-881.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-882.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-883.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-884.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-885.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-886.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-887.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-888.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-889.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-89.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-890.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-891.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-892.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-893.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-894.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-895.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-896.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-897.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-898.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-899.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-9.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-90.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-900.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-901.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-902.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-903.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-904.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-905.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-906.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-907.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-908.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-909.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-91.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-910.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-911.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-912.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-913.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-914.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-915.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-916.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-917.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-918.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-919.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-92.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-920.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-921.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-922.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-923.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-924.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-925.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-926.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-927.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-928.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-929.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-93.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-930.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-931.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-932.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-933.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-934.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-935.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-936.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-937.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-938.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-939.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-94.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-940.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-941.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-942.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-943.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-944.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-945.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-946.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-947.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-948.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-949.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-95.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-950.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-951.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-952.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-953.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-954.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-955.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-956.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-957.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-958.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-959.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-96.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-960.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-961.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-962.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-963.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-964.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-965.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-966.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-967.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-968.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-969.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-97.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-970.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-971.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-972.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-973.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-974.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-975.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-976.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-977.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-978.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-979.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-98.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-980.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-981.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-982.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-983.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-984.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-985.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-986.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-987.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-988.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-989.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-99.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-990.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-991.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-992.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-993.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-994.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-995.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-996.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-997.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-998.png
#   inflating: /content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-999.png

# %%
# !ls -1 "/content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Lung_Opacity/images"| wc -l
# Out:
# 6012

# %%
# !mkdir /content/drive/MyDrive/Xray_train_data

# %%
# !cp -R "/content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/COVID/images" "/content/drive/MyDrive/Xray_train_data/COVID"

# %%
# !ls -1 "/content/drive/MyDrive/Xray_train_data/COVID"| wc -l
# Out:
# 3616

# %%
# !mkdir "/content/drive/MyDrive/Xray_train_data/NORMAL"

# %%
PATH_TO_METADATA = "/content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal.metadata.xlsx"
df = pd.read_excel(PATH_TO_METADATA)
df.head()
# Out:
#   FILE NAME FORMAT     SIZE                                                URL
# 0  NORMAL-1    PNG  256*256  https://www.kaggle.com/c/rsna-pneumonia-detect...
# 1  NORMAL-2    PNG  256*256  https://www.kaggle.com/c/rsna-pneumonia-detect...
# 2  NORMAL-3    PNG  256*256  https://www.kaggle.com/c/rsna-pneumonia-detect...
# 3  NORMAL-4    PNG  256*256  https://www.kaggle.com/c/rsna-pneumonia-detect...
# 4  NORMAL-5    PNG  256*256  https://www.kaggle.com/c/rsna-pneumonia-detect...

# %%
import os
import shutil
cnt = 0
for (i, row) in df.iterrows():
    if (cnt < 3616):
        filename = row["FILE NAME"].lower().capitalize() + "." + row["FORMAT"].lower()
        image_path = os.path.join("/content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Normal/images", filename)
        image_copy_path = os.path.join("/content/drive/MyDrive/Xray_train_data/NORMAL", filename)
        shutil.copy2(image_path, image_copy_path)
        cnt += 1

# %%
print(cnt)
# Out:
# 3616

# %%
# !mkdir "/content/drive/MyDrive/Xray_train_data/Lung_Opacity"

# %%
PATH_TO_METADATA = "/content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Lung_Opacity.metadata.xlsx"
df = pd.read_excel(PATH_TO_METADATA)
df.head()
# Out:
#         FILE NAME FORMAT     SIZE  \
# 0  Lung_Opacity-1    PNG  256*256
# 1  Lung_Opacity-2    PNG  256*256
# 2  Lung_Opacity-3    PNG  256*256
# 3  Lung_Opacity-4    PNG  256*256
# 4  Lung_Opacity-5    PNG  256*256
#
#                                                  URL
# 0  https://www.kaggle.com/c/rsna-pneumonia-detect...
# 1  https://www.kaggle.com/c/rsna-pneumonia-detect...
# 2  https://www.kaggle.com/c/rsna-pneumonia-detect...
# 3  https://www.kaggle.com/c/rsna-pneumonia-detect...
# 4  https://www.kaggle.com/c/rsna-pneumonia-detect...

# %%
import os
import shutil
cnt = 0
for (i, row) in df.iterrows():
    if (cnt < 3616):
        filename = row["FILE NAME"] + "." + row["FORMAT"].lower()
        image_path = os.path.join("/content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Lung_Opacity/images", filename)
        image_copy_path = os.path.join("/content/drive/MyDrive/Xray_train_data/Lung_Opacity", filename)
        shutil.copy2(image_path, image_copy_path)
        cnt += 1
print(cnt)
# Out:
# 3616

# %%
# !mkdir "/content/drive/MyDrive/Xray_train_data/Viral Pneumonia"

# %%
PATH_TO_METADATA = "/content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia.metadata.xlsx"
df = pd.read_excel(PATH_TO_METADATA)
df.head()
# Out:
#            FILE NAME FORMAT     SIZE  \
# 0  Viral Pneumonia-1    PNG  256*256
# 1  Viral Pneumonia-2    PNG  256*256
# 2  Viral Pneumonia-3    PNG  256*256
# 3  Viral Pneumonia-4    PNG  256*256
# 4  Viral Pneumonia-5    PNG  256*256
#
#                                                  URL
# 0  https://www.kaggle.com/paultimothymooney/chest...
# 1  https://www.kaggle.com/paultimothymooney/chest...
# 2  https://www.kaggle.com/paultimothymooney/chest...
# 3  https://www.kaggle.com/paultimothymooney/chest...
# 4  https://www.kaggle.com/paultimothymooney/chest...

# %%
import os
import shutil
cnt = 0
for (i, row) in df.iterrows():
    if (cnt < 3616):
        filename = row["FILE NAME"] + "." + row["FORMAT"].lower()
        image_path = os.path.join("/content/drive/MyDrive/dataset/COVID-19_Radiography_Dataset/Viral Pneumonia/images", filename)
        image_copy_path = os.path.join("/content/drive/MyDrive/Xray_train_data/Viral Pneumonia", filename)
        shutil.copy2(image_path, image_copy_path)
        cnt += 1

# %%
# !ls -1 "/content/drive/MyDrive/Xray_train_data"| wc -l
# Out:
# 4

# %%
# !ls -1 "/content/drive/MyDrive/Xray_train_data/COVID"| wc -l
# Out:
# 3616

# %% [markdown]
# ## **Starting Actual work**

# %%
# !ls -1 "/content/drive/MyDrive/Xray_train_data/Lung_Opacity"| wc -l
# Out:
# 3616

# %%
# !ls -1 "/content/drive/MyDrive/Xray_train_data/Viral Pneumonia"| wc -l
# Out:
# 1345

# %%
train_data_dir= "/content/drive/MyDrive/Xray_train_data"

# %%
IMAGE_SIZE = (256, 256)
IMAGE_SHAPE = IMAGE_SIZE + (3,)

# %% [markdown]
# Importing the libraries

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Input
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
from glob import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
img_height, img_width= IMAGE_SIZE
batch_size=16
train_datagen = ImageDataGenerator(rescale=1./255,zoom_range=0.2,shear_range=0.2,validation_split=0.3)

# %%
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='training')
validation_generator = train_datagen.flow_from_directory(
    train_data_dir, # same directory as training data
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='validation')
# Out:
# Found 5064 images belonging to 2 classes.
# Found 2168 images belonging to 2 classes.

# %% [markdown]
# Resnet model

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.models import Model

# %%
resnet50 = ResNet50(include_top=False,input_shape=(256,256,3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step

# %%
for layer in resnet50.layers:
  layer.trainable=False

# %%
x = Flatten()(resnet50.output)

# %%
output = Dense(1,activation='sigmoid')(x)

# %%
resnet50 = Model(resnet50.input,output)

# %%
resnet50.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 262, 262, 3)          0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 128, 128, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 128, 128, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 128, 128, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 130, 130, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 64, 64, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 64, 64, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 64, 64, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 64, 64, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 64, 64, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 64, 64, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 64, 64, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 64, 64, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 64, 64, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 64, 64, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 64, 64, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 64, 64, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 64, 64, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 64, 64, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 64, 64, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 64, 64, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 64, 64, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 32, 32, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 32, 32, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 32, 32, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 32, 32, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 32, 32, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 32, 32, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 32, 32, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 32, 32, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 32, 32, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 32, 32, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 16, 16, 256)          131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 16, 16, 1024)         525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block6_add[0][0]']
#  on)
#
#  conv5_block1_1_conv (Conv2  (None, 8, 8, 512)            524800    ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_1_bn (BatchNo  (None, 8, 8, 512)            2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, 8, 8, 512)            0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_conv (Conv2  (None, 8, 8, 512)            2359808   ['conv5_block1_1_relu[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 8, 8, 512)            2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, 8, 8, 512)            0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, 8, 8, 2048)           2099200   ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_3_conv (Conv2  (None, 8, 8, 2048)           1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 8, 8, 2048)           8192      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 8, 8, 2048)           8192      ['conv5_block1_3_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 8, 8, 2048)           0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activati  (None, 8, 8, 2048)           0         ['conv5_block1_add[0][0]']
#  on)
#
#  conv5_block2_1_conv (Conv2  (None, 8, 8, 512)            1049088   ['conv5_block1_out[0][0]']
#  D)
#
#  conv5_block2_1_bn (BatchNo  (None, 8, 8, 512)            2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, 8, 8, 512)            0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_conv (Conv2  (None, 8, 8, 512)            2359808   ['conv5_block2_1_relu[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 8, 8, 512)            2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, 8, 8, 512)            0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, 8, 8, 2048)           1050624   ['conv5_block2_2_relu[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, 8, 8, 2048)           8192      ['conv5_block2_3_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, 8, 8, 2048)           0         ['conv5_block1_out[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activati  (None, 8, 8, 2048)           0         ['conv5_block2_add[0][0]']
#  on)
#
#  conv5_block3_1_conv (Conv2  (None, 8, 8, 512)            1049088   ['conv5_block2_out[0][0]']
#  D)
#
#  conv5_block3_1_bn (BatchNo  (None, 8, 8, 512)            2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_relu (Activ  (None, 8, 8, 512)            0         ['conv5_block3_1_bn[0][0]']
#  ation)
#
#  conv5_block3_2_conv (Conv2  (None, 8, 8, 512)            2359808   ['conv5_block3_1_relu[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 8, 8, 512)            2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_2_relu (Activ  (None, 8, 8, 512)            0         ['conv5_block3_2_bn[0][0]']
#  ation)
#
#  conv5_block3_3_conv (Conv2  (None, 8, 8, 2048)           1050624   ['conv5_block3_2_relu[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, 8, 8, 2048)           8192      ['conv5_block3_3_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, 8, 8, 2048)           0         ['conv5_block2_out[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activati  (None, 8, 8, 2048)           0         ['conv5_block3_add[0][0]']
#  on)
#
#  flatten (Flatten)           (None, 131072)               0         ['conv5_block3_out[0][0]']
#
#  dense (Dense)               (None, 1)                    131073    ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 23718785 (90.48 MB)
# Trainable params: 131073 (512.00 KB)
# Non-trainable params: 23587712 (89.98 MB)
# __________________________________________________________________________________________________

# %%
resnet50.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
resnet50.fit(train_generator,validation_data=validation_generator,epochs=5)
# Out:
# Epoch 1/5
# 317/317 [==============================] - 5727s 18s/step - loss: 0.8494 - accuracy: 0.6487 - val_loss: 0.4821 - val_accuracy: 0.7947
# Epoch 2/5
# 317/317 [==============================] - 151s 476ms/step - loss: 0.6039 - accuracy: 0.7291 - val_loss: 0.4372 - val_accuracy: 0.8178
# Epoch 3/5
# 317/317 [==============================] - 150s 475ms/step - loss: 0.7934 - accuracy: 0.7038 - val_loss: 0.9830 - val_accuracy: 0.5729
# Epoch 4/5
# 317/317 [==============================] - 149s 471ms/step - loss: 0.7350 - accuracy: 0.7239 - val_loss: 0.6063 - val_accuracy: 0.7477
# Epoch 5/5
# 317/317 [==============================] - 149s 470ms/step - loss: 0.6616 - accuracy: 0.7330 - val_loss: 0.4179 - val_accuracy: 0.8335

# %%
# Get predictions
probabilities = resnet50.predict(validation_generator)

# Display the probabilities
print(probabilities)
# Out:
# 136/136 [==============================] - 47s 338ms/step
# [[0.98973256]
#  [0.6434379 ]
#  [0.99989045]
#  ...
#  [0.9979254 ]
#  [0.08579028]
#  [0.9466488 ]]

# %%
y_true = validation_generator.classes
y_true
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int32)

# %%
y_pred = probabilities > 0.5
y_pred
# Out:
# array([[ True],
#        [ True],
#        [ True],
#        ...,
#        [ True],
#        [False],
#        [ True]])

# %%
from sklearn.metrics import confusion_matrix
cf_matrix = confusion_matrix(y_true, y_pred)
print(cf_matrix)
# Out:
# [[583 501]
#  [587 497]]

# %%
import seaborn as sns
sns.heatmap(cf_matrix/np.sum(cf_matrix), annot=True,
            fmt='.2%', cmap='Blues')
# Out:
# <Axes: >

# %%
import numpy as np

def calculate_metrics(confusion_matrix):
    # Extract values from the confusion matrix
    TP = confusion_matrix[1, 1]
    TN = confusion_matrix[0, 0]
    FP = confusion_matrix[0, 1]
    FN = confusion_matrix[1, 0]

    # Calculate accuracy
    accuracy = (TP + TN) / np.sum(confusion_matrix)

    # Calculate precision
    precision = TP / (TP + FP) if (TP + FP) != 0 else 0

    # Calculate recall (sensitivity/TPR)
    recall = TP / (TP + FN) if (TP + FN) != 0 else 0

    # Calculate specificity
    specificity = TN / (TN + FP) if (TN + FP) != 0 else 0

    return accuracy, precision, recall, specificity

accuracy, precision, recall, specificity = calculate_metrics(cf_matrix)

print(f'Accuracy: {accuracy:.2f}')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'Specificity: {specificity:.2f}')
# Out:
# Accuracy: 0.50
# Precision: 0.50
# Recall: 0.46
# Specificity: 0.54

# %%
resnet50.save("resnet50.keras")
